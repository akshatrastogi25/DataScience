# %%
import pandas as pd
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Odometer (KM)"].plot();

# %%
plt.style.use("seaborn-whitegrid")

# %%
plt.style.use("seaborn")

# %%
car_sales["Odometer (KM)"].plot();

# %%
plt.style.use("ggplot")
car_sales["Odometer (KM)"].plot();

# %%
 y=np.random.randn(10,4)
y
df=pd.DataFrame(y,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.193939  0.422207 -0.332340  0.089126
# 1 -0.348947  0.005680 -1.614655  1.882084
# 2 -0.227860  0.951575 -0.161902 -0.490139
# 3 -0.253964  1.432895 -0.235301  1.526866
# 4  0.705731  0.342030 -0.854277  0.966097
# 5  0.323870  1.546203 -1.329400  0.559830
# 6  0.490319  0.395080  0.755677  0.825480
# 7 -1.009861  0.231494 -0.024780  1.474592
# 8 -0.092014  2.218287 -0.150894  0.095652
# 9  0.997604  1.974580  0.016674  0.223646

# %%
ax = df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
ax.set(title="Random number Bar Graph from DataFrame",xlabel="Row",ylabel="Random")
ax.legend().set_visible(True)

# %%
ax = df.plot(kind="bar")
ax.set(title="Random number Bar Graph from DataFrame",xlabel="Row",ylabel="Random")
ax.legend().set_visible(True)

# %%
heart_dis=pd.read_csv("heart-disease.csv")
heart_dis.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_45=heart_dis[heart_dis["age"]>45]
over_45
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [239 rows x 14 columns]

# %%
plt.style.use('seaborn-whitegrid')
fig,(ax0,ax1)= plt.subplots(nrows=2,ncols=1,figsize=(10,10))
scatter = ax0.scatter(x=over_45["age"],y=over_45["chol"],c=over_45["target"],cmap="cool");
ax0.set(title="Heart Disease and Cholestrol Levels",xlabel="Age",ylabel="Cholestrol");
ax0.set_xlim([50,80])
ax0.legend(*scatter.legend_elements(),title="Target");
ax0.axhline(over_45["chol"].mean(),linestyle="--");
scatter = ax1.scatter(x=over_45["age"],y=over_45["thalach"],c=over_45["target"],cmap="winter");
ax1.set(title="Heart Disease and Heart Rate Levels",xlabel="Age",ylabel="Max Heart Rate");
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
ax1.legend(*scatter.legend_elements(),title="Target");
ax1.axhline(over_45["thalach"].mean(),linestyle="solid");
fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");
